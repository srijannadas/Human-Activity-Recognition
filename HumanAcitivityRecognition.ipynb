# %% [markdown]
# # Human Activity Recognition

# %%
# !pip install tensorflow-gpu
# !pip install keras
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#      -------------------------------------- 455.9/455.9 MB 3.8 MB/s eta 0:00:00
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# ...
#   Using cached tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# ...
#   Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# ...
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.0
#     Uninstalling tensorboard-2.11.0:
#       Successfully uninstalled tensorboard-2.11.0
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
path='dataset/'
files= os.listdir(path)
files
# Out:
# ['Participant_1.csv',
#  'Participant_10.csv',
#  'Participant_2.csv',
#  'Participant_3.csv',
#  'Participant_4.csv',
#  'Participant_5.csv',
#  'Participant_6.csv',
#  'Participant_7.csv',
#  'Participant_8.csv',
#  'Participant_9.csv']

# %%
df=pd.read_csv(path+files[0],header=1)
df.head()
# Out:
#      time_stamp       Ax      Ay       Az       Lx      Ly       Lz       Gx  \
# 0  1.390000e+12 -1.81150 -14.873 -1.34840 -1.26910 -5.1057 -0.66445 -0.53206
# 1  1.390000e+12  0.24517 -14.070 -0.84446  0.70147 -4.2969 -0.17199 -0.25229
# 2  1.390000e+12 -0.57205 -14.628 -1.75700 -0.21760 -4.8531 -1.05650 -1.04920
# 3  1.390000e+12 -0.69464 -12.939 -3.09180 -0.32273 -3.1786 -2.21970 -2.37200
# 4  1.390000e+12  0.87170 -12.000 -1.56630  1.13740 -2.2390 -0.65476 -2.79010
#
#         Gy       Gz  ...    Lx.4     Ly.4      Lz.4     Gx.4     Gy.4  \
# 0 -3.18690  0.23976  ... -5.3574 -0.95749  0.318860  0.52565 -0.18815
# 1 -1.79660  0.40745  ... -4.5352 -0.67629  0.081656  0.43616  0.16371
# 2  0.29138  0.29230  ... -4.0408 -0.55974 -0.523690  0.32284  0.43127
# 3  1.00820  0.34972  ... -3.5908  0.15795 -1.880200  0.20403  0.72846
# 4  0.65485  0.22724  ... -1.9450  0.85796 -2.995300  0.09896  0.94379
#
#        Gz.4   Mx.4  My.4  Mz.4  Unnamed: 69
# ...

# %% [markdown]
# # Visuals of data while Walking

# %%
plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="walking"][:100], label='X-axis')
plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="walking"][:100], label='Y-axis')
plt.plot(np.arange(0,100),df.Az[df['Unnamed: 69']=="walking"][:100], label='Z-axis')
plt.legend()

# %% [markdown]
# # Visuals of Data while Standing

# %%
plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="standing"][:100], label='X-axis')
plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="standing"][:100], label='Y-axis')
plt.plot(np.arange(0,100),df.Az[df['Unnamed: 69']=="standing"][:100], label='Z-axis')
plt.legend()
# Out:
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\3044962842.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="standing"][:100], label='X-axis')
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\3044962842.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="standing"][:100], label='Y-axis')
# ...

# %% [markdown]
# # Visuals of Data while Running

# %%
plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="jogging"][:100], label='X-axis')
plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="jogging"][:100], label='Y-axis')
plt.plot(np.arange(0,100),df.Az[df['Unnamed: 69']=="jogging"][:100], label='Z-axis')
plt.legend()
# Out:
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\2807345162.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="jogging"][:100], label='X-axis')
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\2807345162.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="jogging"][:100], label='Y-axis')
# ...

# %% [markdown]
# # Visuals of Data while Sitting

# %%
plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="sitting"][:100], label='X-axis')
plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="sitting"][:100], label='Y-axis')
plt.plot(np.arange(0,100),df.Az[df['Unnamed: 69']=="sitting"][:100], label='Z-axis')
plt.legend()
# Out:
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\3312786046.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="sitting"][:100], label='X-axis')
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\3312786046.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="sitting"][:100], label='Y-axis')
# ...

# %% [markdown]
# # Visuals of Data while going Upstairs

# %%
plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="upstairs"][:100], label='X-axis')
plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="upstairs"][:100], label='Y-axis')
plt.plot(np.arange(0,100),df.Az[df['Unnamed: 69']=="upstairs"][:100], label='Z-axis')
plt.legend()
# Out:
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\2520150461.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="upstairs"][:100], label='X-axis')
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\2520150461.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="upstairs"][:100], label='Y-axis')
# ...

# %% [markdown]
# # Visuals of Data while going Downstairs

# %%
plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="downstairs"][:100], label='X-axis')
plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="downstairs"][:100], label='Y-axis')
plt.plot(np.arange(0,100),df.Az[df['Unnamed: 69']=="downstairs"][:100], label='Z-axis')
plt.legend()
# Out:
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\2864424439.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="downstairs"][:100], label='X-axis')
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\2864424439.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="downstairs"][:100], label='Y-axis')
# ...

# %% [markdown]
# # Visuals of Data while biking

# %%
plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="biking"][:100], label='X-axis')
plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="biking"][:100], label='Y-axis')
plt.plot(np.arange(0,100),df.Az[df['Unnamed: 69']=="biking"][:100], label='Z-axis')
plt.legend()
# Out:
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\2304871265.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ax[df['Unnamed: 69']=="biking"][:100], label='X-axis')
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\2304871265.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0,100),df.Ay[df['Unnamed: 69']=="biking"][:100], label='Y-axis')
# ...

# %% [markdown]
# # Merging all datasets into single dataframe

# %%
df=pd.DataFrame()

for file in files:
    df_temp=pd.read_csv(path+file, header=1)
    df=pd.concat([df,df_temp], sort= False)
df
# Out:
#          time_stamp       Ax       Ay       Az        Lx        Ly        Lz  \
# 0      1.390000e+12 -1.81150 -14.8730 -1.34840 -1.269100 -5.105700 -0.664450
# 1      1.390000e+12  0.24517 -14.0700 -0.84446  0.701470 -4.296900 -0.171990
# 2      1.390000e+12 -0.57205 -14.6280 -1.75700 -0.217600 -4.853100 -1.056500
# 3      1.390000e+12 -0.69464 -12.9390 -3.09180 -0.322730 -3.178600 -2.219700
# 4      1.390000e+12  0.87170 -12.0000 -1.56630  1.137400 -2.239000 -0.654760
# ...             ...      ...      ...      ...       ...       ...       ...
# 62995  1.390000e+12 -3.11910  -9.0167 -1.51190  2.289100 -0.836530 -1.422500
# 62996  1.390000e+12 -4.56280  -7.5321  0.70826  0.843960  0.648940  0.615980
# 62997  1.390000e+12 -5.40730  -7.8045  0.87170 -0.022973  0.389340  0.668480
# 62998  1.390000e+12 -6.04740  -8.1177  0.25879 -0.695410  0.094103 -0.044593
# 62999  1.390000e+12 -6.12920  -8.3493 -1.26670 -0.798490 -0.127550 -1.663900
#
# ...

# %%
df.columns
# Out:
# Index(['time_stamp', 'Ax', 'Ay', 'Az', 'Lx', 'Ly', 'Lz', 'Gx', 'Gy', 'Gz',
#        'Mx', 'My', 'Mz', 'Unnamed: 13', 'time_stamp.1', 'Ax.1', 'Ay.1', 'Az.1',
#        'Lx.1', 'Ly.1', 'Lz.1', 'Gx.1', 'Gy.1', 'Gz.1', 'Mx.1', 'My.1', 'Mz.1',
#        'Unnamed: 27', 'time_stamp.2', 'Ax.2', 'Ay.2', 'Az.2', 'Lx.2', 'Ly.2',
#        'Lz.2', 'Gx.2', 'Gy.2', 'Gz.2', 'Mx.2', 'My.2', 'Mz.2', 'Unnamed: 41',
#        'time_stamp.3', 'Ax.3', 'Ay.3', 'Az.3', 'Lx.3', 'Ly.3', 'Lz.3', 'Gx.3',
#        'Gy.3', 'Gz.3', 'Mx.3', 'My.3', 'Mz.3', 'Unnamed: 55', 'time_stamp.4',
#        'Ax.4', 'Ay.4', 'Az.4', 'Lx.4', 'Ly.4', 'Lz.4', 'Gx.4', 'Gy.4', 'Gz.4',
#        'Mx.4', 'My.4', 'Mz.4', 'Unnamed: 69'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# time_stamp
# Ax
# Ay
# Az
# Lx
# Ly
# Lz
# Gx
# Gy
# Gz
# Mx
# My
# Mz
# Unnamed: 13
# time_stamp.1
# Ax.1
# Ay.1
# Az.1
# Lx.1
# Ly.1
# Lz.1
# Gx.1
# Gy.1
# Gz.1
# Mx.1
# My.1
# Mz.1
# Unnamed: 27
# time_stamp.2
# Ax.2
# Ay.2
# Az.2
# Lx.2
# Ly.2
# Lz.2
# Gx.2
# Gy.2
# Gz.2
# Mx.2
# My.2
# Mz.2
# Unnamed: 41
# time_stamp.3
# Ax.3
# Ay.3
# Az.3
# Lx.3
# Ly.3
# Lz.3
# Gx.3
# Gy.3
# Gz.3
# Mx.3
# My.3
# Mz.3
# Unnamed: 55
# time_stamp.4
# Ax.4
# Ay.4
# Az.4
# Lx.4
# Ly.4
# Lz.4
# Gx.4
# Gy.4
# Gz.4
# Mx.4
# My.4
# Mz.4
# Unnamed: 69

# %% [markdown]
# # Splitting data of left and right pocket

# %%
left_pocket = df[df.columns[1:13]]
left_pocket
# Out:
#             Ax       Ay       Az        Lx        Ly        Lz        Gx  \
# 0     -1.81150 -14.8730 -1.34840 -1.269100 -5.105700 -0.664450 -0.532060
# 1      0.24517 -14.0700 -0.84446  0.701470 -4.296900 -0.171990 -0.252290
# 2     -0.57205 -14.6280 -1.75700 -0.217600 -4.853100 -1.056500 -1.049200
# 3     -0.69464 -12.9390 -3.09180 -0.322730 -3.178600 -2.219700 -2.372000
# 4      0.87170 -12.0000 -1.56630  1.137400 -2.239000 -0.654760 -2.790100
# ...        ...      ...      ...       ...       ...       ...       ...
# 62995 -3.11910  -9.0167 -1.51190  2.289100 -0.836530 -1.422500  0.430050
# 62996 -4.56280  -7.5321  0.70826  0.843960  0.648940  0.615980  0.197920
# 62997 -5.40730  -7.8045  0.87170 -0.022973  0.389340  0.668480  0.193340
# 62998 -6.04740  -8.1177  0.25879 -0.695410  0.094103 -0.044593  0.188760
# 62999 -6.12920  -8.3493 -1.26670 -0.798490 -0.127550 -1.663900  0.081856
#
#             Gy        Gz     Mx     My     Mz
# ...

# %%
right_pocket = df[df.columns[15:27]]
right_pocket.columns=left_pocket.columns
right_pocket
# Out:
#             Ax       Ay        Az       Lx       Ly       Lz       Gx  \
# 0     -1.19860 -13.8520  3.786500 -1.76980 -4.06250  3.89850 -3.62550
# 1     -2.38360 -16.5900  2.996500 -2.70250 -6.78900  2.86820 -3.48990
# 2     -4.63090 -16.6030  2.070300 -4.34550 -6.80810  1.68890 -3.38510
# 3     -4.78070 -16.4530  1.157700 -4.19540 -6.67310  0.74084 -3.10170
# 4     -0.92618 -12.1900 -1.062400 -0.18116 -2.41440 -1.28500 -2.75870
# ...        ...      ...       ...      ...      ...      ...      ...
# 62995  3.86820  -9.9020  0.354130  3.55870 -0.18493 -0.93169 -0.20617
# 62996  3.94990  -9.5206  0.054481  3.63060  0.20627 -1.15210 -0.25137
# 62997  3.43230  -9.4798 -0.313270  3.09120  0.24997 -1.49070 -0.13531
# 62998  2.43800  -9.5615 -0.858080  2.04180  0.17223 -1.98430 -0.16768
# 62999  2.77860 -10.0380  0.490330  2.28560 -0.29845 -0.54154 -0.43768
#
#             Gy        Gz     Mx     My    Mz
# 0      1.07390  0.136220  18.84  55.92 -6.72
# ...

# %% [markdown]
# # Concatenate Leftpocket Data and Rightpocket Data

# %%
train_df= pd.concat([left_pocket,right_pocket],sort=False)

# %%
train_df
# Out:
#             Ax       Ay        Az       Lx       Ly       Lz       Gx  \
# 0     -1.81150 -14.8730 -1.348400 -1.26910 -5.10570 -0.66445 -0.53206
# 1      0.24517 -14.0700 -0.844460  0.70147 -4.29690 -0.17199 -0.25229
# 2     -0.57205 -14.6280 -1.757000 -0.21760 -4.85310 -1.05650 -1.04920
# 3     -0.69464 -12.9390 -3.091800 -0.32273 -3.17860 -2.21970 -2.37200
# 4      0.87170 -12.0000 -1.566300  1.13740 -2.23900 -0.65476 -2.79010
# ...        ...      ...       ...      ...      ...      ...      ...
# 62995  3.86820  -9.9020  0.354130  3.55870 -0.18493 -0.93169 -0.20617
# 62996  3.94990  -9.5206  0.054481  3.63060  0.20627 -1.15210 -0.25137
# 62997  3.43230  -9.4798 -0.313270  3.09120  0.24997 -1.49070 -0.13531
# 62998  2.43800  -9.5615 -0.858080  2.04180  0.17223 -1.98430 -0.16768
# 62999  2.77860 -10.0380  0.490330  2.28560 -0.29845 -0.54154 -0.43768
#
#             Gy        Gz     Mx     My    Mz
# 0     -3.18690  0.239760  12.72  40.74 -6.00
# ...

# %%
Labels= pd.concat([df['Unnamed: 69'],df['Unnamed: 69']], axis=0, sort= False)
Labels.columns=['Activity']

# %%
Labels
# Out:
# 0           walking
# 1           walking
# 2           walking
# 3           walking
# 4           walking
#             ...
# 62995    downstairs
# 62996    downstairs
# 62997    downstairs
# 62998    downstairs
# 62999    downstairs
# Name: Unnamed: 69, Length: 1260000, dtype: object

# %% [markdown]
# # Adding Acitivity Labels in main df

# %%
train_df['Activity']=Labels
train_df
# Out:
#             Ax       Ay        Az       Lx       Ly       Lz       Gx  \
# 0     -1.81150 -14.8730 -1.348400 -1.26910 -5.10570 -0.66445 -0.53206
# 1      0.24517 -14.0700 -0.844460  0.70147 -4.29690 -0.17199 -0.25229
# 2     -0.57205 -14.6280 -1.757000 -0.21760 -4.85310 -1.05650 -1.04920
# 3     -0.69464 -12.9390 -3.091800 -0.32273 -3.17860 -2.21970 -2.37200
# 4      0.87170 -12.0000 -1.566300  1.13740 -2.23900 -0.65476 -2.79010
# ...        ...      ...       ...      ...      ...      ...      ...
# 62995  3.86820  -9.9020  0.354130  3.55870 -0.18493 -0.93169 -0.20617
# 62996  3.94990  -9.5206  0.054481  3.63060  0.20627 -1.15210 -0.25137
# 62997  3.43230  -9.4798 -0.313270  3.09120  0.24997 -1.49070 -0.13531
# 62998  2.43800  -9.5615 -0.858080  2.04180  0.17223 -1.98430 -0.16768
# 62999  2.77860 -10.0380  0.490330  2.28560 -0.29845 -0.54154 -0.43768
#
#             Gy        Gz     Mx     My    Mz    Activity
# 0     -3.18690  0.239760  12.72  40.74 -6.00     walking
# ...

# %%
train_df.Activity.unique()
# Out:
# array(['walking', 'standing', 'jogging', 'sitting', 'biking', 'upstairs',
#        'downstairs', 'upsatirs'], dtype=object)

# %%
train_df.Activity.loc[(train_df.Activity=='upsatirs')]='upstairs'
train_df.Activity.unique()
# Out:
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\1963269361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.Activity.loc[(train_df.Activity=='upsatirs')]='upstairs'
# array(['walking', 'standing', 'jogging', 'sitting', 'biking', 'upstairs',
#        'downstairs'], dtype=object)

# %%
train_df.Activity.unique()
# Out:
# array(['walking', 'standing', 'jogging', 'sitting', 'biking', 'upstairs',
#        'downstairs'], dtype=object)

# %% [markdown]
# # Preprocessing

# %%
X_train = train_df[train_df.columns[0:12]]
y_train = train_df[train_df.columns[12:13]]

# %%
X_train
# Out:
#             Ax       Ay        Az       Lx       Ly       Lz       Gx  \
# 0     -1.81150 -14.8730 -1.348400 -1.26910 -5.10570 -0.66445 -0.53206
# 1      0.24517 -14.0700 -0.844460  0.70147 -4.29690 -0.17199 -0.25229
# 2     -0.57205 -14.6280 -1.757000 -0.21760 -4.85310 -1.05650 -1.04920
# 3     -0.69464 -12.9390 -3.091800 -0.32273 -3.17860 -2.21970 -2.37200
# 4      0.87170 -12.0000 -1.566300  1.13740 -2.23900 -0.65476 -2.79010
# ...        ...      ...       ...      ...      ...      ...      ...
# 62995  3.86820  -9.9020  0.354130  3.55870 -0.18493 -0.93169 -0.20617
# 62996  3.94990  -9.5206  0.054481  3.63060  0.20627 -1.15210 -0.25137
# 62997  3.43230  -9.4798 -0.313270  3.09120  0.24997 -1.49070 -0.13531
# 62998  2.43800  -9.5615 -0.858080  2.04180  0.17223 -1.98430 -0.16768
# 62999  2.77860 -10.0380  0.490330  2.28560 -0.29845 -0.54154 -0.43768
#
#             Gy        Gz     Mx     My    Mz
# 0     -3.18690  0.239760  12.72  40.74 -6.00
# ...

# %%
y_train
# Out:
#          Activity
# 0         walking
# 1         walking
# 2         walking
# 3         walking
# 4         walking
# ...           ...
# 62995  downstairs
# 62996  downstairs
# 62997  downstairs
# 62998  downstairs
# 62999  downstairs
#
# [1260000 rows x 1 columns]

# %%
#since Label is in string format we need to change the datatype into float or int
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
y_train=encode.fit_transform(y_train)
y_train[0:12]
# Out:
# C:\Users\isteb\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6])

# %% [markdown]
# # Splitting training data into training and test data

# %%
def train_test_split(X,y, split_size=0.75):
    split= int (len(X) * split_size)
    train_x = X[:split]
    train_y = y[:split]
    test_x = X[split:]
    test_y = y[split:]
    return train_x,test_x, train_y, test_y
X_train, X_test, y_train,y_test = train_test_split(X_train, y_train)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (945000, 12)
# (945000,)
# (315000, 12)
# (315000,)

# %% [markdown]
# # Converting dataset into time series sequence

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

n_time_steps = 100
n_features = 12
train_gen = TimeseriesGenerator(X_train.to_numpy(), y_train, length=n_time_steps, batch_size=512)
test_gen = TimeseriesGenerator(X_test.to_numpy(), y_test, length=n_time_steps, batch_size=512)

# %%
from keras.models import Sequential # linear Stack of Layer
from keras.layers import Dense, Flatten, LSTM #Regular layer contains feed,N dim. into 1 dim vector, and LSTM contain LSTM cell 
from keras.regularizers import l2
from keras.optimizers import Adam # optimiser/GD to converge neural Network

# %%
model=Sequential()
model.add(LSTM(32, return_sequences=True, input_shape= (n_time_steps,n_features), kernel_regularizer= l2(0.000001),bias_regularizer=l2(0.000001),name='lstm_1'))
model.add(Flatten(name='flatten'))
model.add(Dense(64, activation='relu', kernel_regularizer = l2(0.000001),bias_regularizer = l2(0.000001),name='dense_1'))
model.add(Dense(len(np.unique(y_train)),activation='softmax', kernel_regularizer=l2(0.000001), bias_regularizer = l2(0.000001), name='Output'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_1 (LSTM)               (None, 100, 32)           5760
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense_1 (Dense)             (None, 64)                204864
#
#  Output (Dense)              (None, 7)                 455
#
# ...
# Total params: 211,079
# Trainable params: 211,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint
callbacks=[ModelCheckpoint('model.h5', save_weights_only=False, save_best_only=True, verbose=1)]

# %% [markdown]
# # Training

# %%
history=model.fit_generator(train_gen, epochs=5, validation_data= test_gen, callbacks=callbacks)
# Out:
# Epoch 1/5
# C:\Users\isteb\AppData\Local\Temp\ipykernel_13016\3936883625.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(train_gen, epochs=5, validation_data= test_gen, callbacks=callbacks)
# 1846/1846 [==============================] - ETA: 0s - loss: 0.7499 - accuracy: 0.7200
# Epoch 1: val_loss improved from inf to 1.14045, saving model to model.h5
# 1846/1846 [==============================] - 418s 226ms/step - loss: 0.7499 - accuracy: 0.7200 - val_loss: 1.1405 - val_accuracy: 0.6762
# Epoch 2/5
# 1846/1846 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9267
# Epoch 2: val_loss improved from 1.14045 to 0.66328, saving model to model.h5
# 1846/1846 [==============================] - 425s 230ms/step - loss: 0.2296 - accuracy: 0.9267 - val_loss: 0.6633 - val_accuracy: 0.8205
# Epoch 3/5
# ...

# %%
from keras.models import load_model
model=load_model('model.h5')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_1 (LSTM)               (None, 100, 32)           5760
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense_1 (Dense)             (None, 64)                204864
#
#  Output (Dense)              (None, 7)                 455
#
# ...
# Total params: 211,079
# Trainable params: 211,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Exporting the Model

# %%
from keras import backend as k
from tensorflow.python.tools import freeze_graph, optimize_for_inference_lib
import tensorflow as tf

input_node_name = ['lstm_1_input']
output_node_name = 'output/Softmax'
model_name='har_model'

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
import numpy as np
#path of the directory where you want to save your model
frozen_out_path = ''
# name of the .pb file
frozen_graph_filename = "frozen_graph"
# Convert Keras model to ConcreteFunction
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))
# Get frozen ConcreteFunction
frozen_func = convert_variables_to_constants_v2(full_model)
frozen_func.graph.as_graph_def()
layers = [op.name for op in frozen_func.graph.get_operations()]
print("-" * 60)
print("Frozen model layers: ")
for layer in layers:
    print(layer)
print("-" * 60)
print("Frozen model inputs: ")
print(frozen_func.inputs)
print("Frozen model outputs: ")
print(frozen_func.outputs)
# Save frozen graph to disk
tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
                  logdir=frozen_out_path,
                  name=f"{frozen_graph_filename}.pb",
                  as_text=False)
# Save its text representation
tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
                  logdir=frozen_out_path,
                  name=f"{frozen_graph_filename}.pbtxt",
                  as_text=True)
# Out:
# ------------------------------------------------------------
# Frozen model layers:
# x
# sequential_1/lstm_1/zeros_1/packed/1
# sequential_1/lstm_1/zeros_1/Const
# sequential_1/lstm_1/strided_slice/stack
# sequential_1/lstm_1/strided_slice/stack_1
# sequential_1/lstm_1/strided_slice/stack_2
# sequential_1/lstm_1/PartitionedCall/transpose/perm
# sequential_1/lstm_1/PartitionedCall/TensorArrayUnstack/TensorListFromTensor/element_shape
# sequential_1/lstm_1/PartitionedCall/time
# sequential_1/lstm_1/PartitionedCall/while/loop_counter
# sequential_1/lstm_1/PartitionedCall/strided_slice/stack
# sequential_1/lstm_1/PartitionedCall/strided_slice/stack_1
# sequential_1/lstm_1/PartitionedCall/strided_slice/stack_2
# sequential_1/lstm_1/zeros/packed/1
# sequential_1/lstm_1/zeros/Const
# sequential_1/lstm_1/PartitionedCall/TensorArrayV2_1/element_shape
# sequential_1/lstm_1/Read_2/ReadVariableOp/resource
# sequential_1/lstm_1/Read_1/ReadVariableOp/resource
# ...
